# %%
for python_version in $LINCS_DEV_PYTHON_VERSIONS
do
  echo "Python $python_version"

  python$python_version -m lincs generate classification-problem 4 3 --random-seed 208978669

done
# Out:
# Python 3.8
# # Reproduction command (with lincs version 1.1.1.dev0): lincs generate classification-problem 4 3 --random-seed 208978669
# kind: classification-problem
# format_version: 1
# criteria:
#   - name: Criterion 1
#     value_type: real
#     preference_direction: increasing
#     min_value: 0
#     max_value: 1
#   - name: Criterion 2
#     value_type: real
#     preference_direction: increasing
#     min_value: 0
#     max_value: 1
#   - name: Criterion 3
#     value_type: real
#     preference_direction: increasing
#     min_value: 0
#     max_value: 1
#   - name: Criterion 4
#     value_type: real
#     preference_direction: increasing
#     min_value: 0
#     max_value: 1
# ordered_categories:
#   - name: Worst category
#   - name: Intermediate category 1
#   - name: Best category
# Python 3.9
# # Reproduction command (with lincs version 1.1.1.dev0): lincs generate classification-problem 4 3 --random-seed 208978669
# kind: classification-problem
# format_version: 1
# ...
